# %% [markdown]
# <a href="https://colab.research.google.com/github/paulinadopke/data-science-bootcamp/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello word')
# Out:
# Hello word

# %% [markdown]
# ### Tekst
